# %%
dataset_in = "datasets/doccano_output.jsonl"

labels = ["Model urządzenia",
          "RAM / VRAM",
          "Pamięć",
          "Kolor",
          "Przekątna ekranu"]

# %%
import json

with open(dataset_in, "r") as f:
    for line in f.readlines():
        print(json.loads(line))
# Out:
# {'text': 'Sprzedam telefon Sony Xperia E3', 'labels': [[17, 31, 'Model urządzenia']]}
# {'text': 'Nowy nieodpakowany Xiaomi Mi11 z polskiej dystrybucji. Kupiony na promocji. Do odbioru osobistego od 10 marca :)', 'labels': []}
# {'text': 'Cisco Linksys E1200 Router używany, sprawny zapraszam do kupna, możliwość wysyłki.', 'labels': []}
# {'text': 'Laptop 100% sprawny, zainstalowany świeży system, wymieniona pasta termoprzewodząca -  gotowy do pracy.', 'labels': []}
# {'text': 'Sprzedam drukarkę Anycubic I3 MEGA. używana w stanie BDB. Pod koniec 2020 sprowadzona przeze mnie z dalekiego wschodu. Łącznie wydrukowała może z 1kg PLA i 1kg PET, głównie części do zabawek. Stalowa sztywna rama. Jak za tą cenę to wydruki całkiem przyzwoite. Szukam czegoś z większym polem roboczym. W zestawie wszystko co było od nowości. Możliwa wysyłka kurierem DHL lub DPD. Dorzucę 1kg PLA w losowym kolorze', 'labels': [[18, 29, 'Model urządzenia']]}
# ...
